# %% [markdown]
# ## BOJ 2579_계단 오르기
# ### 문제
# 계단 오르기 게임은 계단 아래 시작점부터 계단 꼭대기에 위치한 도착점까지 가는 게임이다. <그림 1>과 같이 각각의 계단에는 일정한 점수가 쓰여 있는데 계단을 밟으면 그 계단에 쓰여 있는 점수를 얻게 된다.
#
# ![image.png](attachment:3f534bd3-7fc1-40fa-8665-2513035d1286.png)
# <그림 1>
#
# 예를 들어 <그림 2>와 같이 시작점에서부터 첫 번째, 두 번째, 네 번째, 여섯 번째 계단을 밟아 도착점에 도달하면 총 점수는 10 + 20 + 25 + 20 = 75점이 된다.
#
# ![image.png](attachment:29189c9c-fcda-4739-b37d-e428d69cbce7.png)
#                            <그림 2>
#
# 계단 오르는 데는 다음과 같은 규칙이 있다.
#
# 계단은 한 번에 한 계단씩 또는 두 계단씩 오를 수 있다. 즉, 한 계단을 밟으면서 이어서 다음 계단이나, 다음 다음 계단으로 오를 수 있다.
# 연속된 세 개의 계단을 모두 밟아서는 안 된다. 단, 시작점은 계단에 포함되지 않는다.
# 마지막 도착 계단은 반드시 밟아야 한다.
# 따라서 첫 번째 계단을 밟고 이어 두 번째 계단이나, 세 번째 계단으로 오를 수 있다. 하지만, 첫 번째 계단을 밟고 이어 네 번째 계단으로 올라가거나, 첫 번째, 두 번째, 세 번째 계단을 연속해서 모두 밟을 수는 없다.
#
# 각 계단에 쓰여 있는 점수가 주어질 때 이 게임에서 얻을 수 있는 총 점수의 최댓값을 구하는 프로그램을 작성하시오.

# %% [markdown]
# ### 풀이방법
# - 빈 dp 생성
# - 0번째에 가장 큰 값은 list[0], 1번째에서 가장 큰 값은 list[0]+list[1], 2번째에서 가장 큰 값은 0번째와 1번째 중에 큰값에 n_list[2]를 더한 값
# - 3번째부터는 dp알고리즘을 따라야함

# %%
# import sys
# input = sys.stdin.readline
N = int(input())
n_list = []
for _ in range(N):
    n_list.append(int(input()))
    
dp = [0 for _ in range(N)]
if N==1:
    print(n_list[0])
elif N==2:
    print(n_list[0]+n_list[1])
else: 
    dp[0], dp[1] = n_list[0], n_list[0]+n_list[1]
    dp[2] = max(n_list[0], n_list[1])+n_list[2]
    for n in range(3, N):
        dp[n] = max(dp[n-2], dp[n-3]+n_list[n-1])+n_list[n]
    print(dp[N-1])
# Out:
#  2
#  10
#  20
# 30
