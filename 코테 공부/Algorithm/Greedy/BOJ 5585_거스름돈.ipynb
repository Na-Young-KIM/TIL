# %% [markdown]
# # BOJ 5585: 거스름돈
#
# ## 문제
# 타로는 자주 JOI잡화점에서 물건을 산다. JOI잡화점에는 잔돈으로 500엔, 100엔, 50엔, 10엔, 5엔, 1엔이 충분히 있고, 언제나 거스름돈 개수가 가장 적게 잔돈을 준다. 타로가 JOI잡화점에서 물건을 사고 카운터에서 1000엔 지폐를 한장 냈을 때, 받을 잔돈에 포함된 잔돈의 개수를 구하는 프로그램을 작성하시오.
#
# ## 입력
# 입력은 한줄로 이루어져있고, 타로가 지불할 돈(1 이상 1000미만의 정수) 1개가 쓰여져있다.
#
# ## 출력
# 제출할 출력 파일은 1행으로만 되어 있다. 잔돈에 포함된 매수를 출력하시오.
#
# ## 예제입력1
# 380
#
# ## 예제출력1
# 4
#
# ## 예제입력2
# 1
#
# ## 예제출력2
# 15

# %% [markdown]
# ## 내가 푼 풀이
# - for문을 최대한 사용하지 않고 풀어서, 메모리와 속도를 높이려고 했다.

# %%
a = 1000 - int(input())
b = 0

b += a//500
a %= 500
b += a//100
a %= 100
b += a//50
a %= 50
b += a//10
a %= 10
b += a//5
a %= 5
b += a

print(b)
# Out:
#  1
# 15

# %% [markdown]
# ![image.png](attachment:aef172bd-8c25-4e66-9bcc-5ee28c7e5e1f.png)

# %% [markdown]
# ## 다른 사람 풀이
# - 오히려 for문을 사용하는 것이 메모리를 더 적게 쓰고, 더 적은 시간이 걸렸다. 왜..?

# %%
n=1000-int(input())
D=[500,100,50,10,5,1]
ans=0
for i in range(6):
    ans+=n//D[i]
    n-=n//D[i]*D[i]
print(ans)

# %% [markdown]
# ![image.png](attachment:1a8e3131-ff55-458d-9f4a-1538954df4e3.png)
